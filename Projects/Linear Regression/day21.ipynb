# %%
# Machine Learning ML
# sklearn library will be needed for ml 
# Linear Regression

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

df = pd.read_csv('Used_Bikes.csv')
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
# duplicates record
print("Number of Duplicated Record : ",df.duplicated().sum())
# Out:
# Number of Duplicated Record :  25324

# %%
df.drop_duplicates(inplace=True)
print("Duplicates Removed!")
# Out:
# Duplicates Removed!

# %%
print("Number of Duplicated Record : ",df.duplicated().sum())
# Out:
# Number of Duplicated Record :  0

# %%
print("Total number of bike Record : ",df.shape[0])
# Out:
# Total number of bike Record :  7324

# %%
# missing value check in data
df.isnull().sum()
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
# ML only deals with numerical value
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
cat_col = df.select_dtypes(include='O')
cat_col.head()
# Out:
#                               bike_name       city        owner          brand
# 0    TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner            TVS
# 1           Royal Enfield Classic 350cc      Delhi  First Owner  Royal Enfield
# 2                  Triumph Daytona 675R      Delhi  First Owner        Triumph
# 3                  TVS Apache RTR 180cc  Bangalore  First Owner            TVS
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner         Yamaha

# %%
num_col = df.select_dtypes(exclude='O')
num_col
# Out:
#          price  kms_driven  age  power
# 0      35000.0     17654.0  3.0  110.0
# 1     119900.0     11000.0  4.0  350.0
# 2     600000.0       110.0  8.0  675.0
# 3      65000.0     16329.0  4.0  180.0
# 4      80000.0     10000.0  3.0  150.0
# ...        ...         ...  ...    ...
# 9362   25000.0     48587.0  8.0  150.0
# 9369   35000.0     60000.0  9.0  220.0
# 9370  450000.0      3430.0  4.0  750.0
# 9371  139000.0     21300.0  4.0  400.0
# 9372   80000.0      7127.0  5.0  220.0
#
# [7324 rows x 4 columns]

# %%
cat_col['owner'].value_counts()
# Out:
# owner
# First Owner             6642
# Second Owner             588
# Third Owner               84
# Fourth Owner Or More      10
# Name: count, dtype: int64

# %%
# Data Transformation
dt = {'First Owner':1,'Second Owner':2,'Third Owner':3,
      'Fourth Owner Or More':4}
dt
# Out:
# {'First Owner': 1,
#  'Second Owner': 2,
#  'Third Owner': 3,
#  'Fourth Owner Or More': 4}

# %%
df['owner'] = df['owner'].map(dt) # single time execute

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#       owner  age  power            brand
# 0         1  3.0  110.0              TVS
# 1         1  4.0  350.0    Royal Enfield
# 2         1  8.0  675.0          Triumph
# 3         1  4.0  180.0              TVS
# 4         1  3.0  150.0           Yamaha
# ...     ...  ...    ...              ...
# 9362      1  8.0  150.0             Hero
# 9369      1  9.0  220.0            Bajaj
# 9370      1  4.0  750.0  Harley-Davidson
# 9371      1  4.0  400.0            Bajaj
# 9372      1  5.0  220.0            Bajaj
#
# [7324 rows x 8 columns]

# %%
df['brand'].value_counts()
# Out:
# brand
# Bajaj              2081
# Royal Enfield      1346
# Hero               1142
# Honda               676
# Yamaha              651
# TVS                 481
# KTM                 375
# Suzuki              203
# Harley-Davidson      91
# Kawasaki             61
# Hyosung              53
# Mahindra             50
# Benelli              46
# Triumph              21
# Ducati               20
# BMW                  10
# Jawa                  7
# Indian                3
# MV                    3
# Rajdoot               1
# LML                   1
# Yezdi                 1
# Ideal                 1
# Name: count, dtype: int64

# %%
# Get the brands that appear at least 10 times
bike_brand = list(df['brand'].value_counts().head(16).index)
bike_brand
# Out:
# ['Bajaj',
#  'Royal Enfield',
#  'Hero',
#  'Honda',
#  'Yamaha',
#  'TVS',
#  'KTM',
#  'Suzuki',
#  'Harley-Davidson',
#  'Kawasaki',
#  'Hyosung',
#  'Mahindra',
#  'Benelli',
#  'Triumph',
#  'Ducati',
#  'BMW']

# %%
df2 = df[df['brand'].isin(bike_brand)]
df2.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#    owner  age  power          brand
# 0      1  3.0  110.0            TVS
# 1      1  4.0  350.0  Royal Enfield
# 2      1  8.0  675.0        Triumph
# 3      1  4.0  180.0            TVS
# 4      1  3.0  150.0         Yamaha

# %%
br = {'Bajaj':1,
 'Royal Enfield':2,
 'Hero':3,
 'Honda':4,
 'Yamaha':5,
 'TVS':6,
 'KTM':7,
 'Suzuki':8,
 'Harley-Davidson':9,
 'Kawasaki':10,
 'Hyosung':11,
 'Mahindra':12,
 'Benelli':13,
 'Triumph':14,
 'Ducati':15,
 'BMW':16}

df2['brand'] = df2['brand'].map(br) # label encoding
df2.head()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8708\936175165.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['brand'] = df2['brand'].map(br) # label encoding
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#    owner  age  power  brand
# 0      1  3.0  110.0      6
# 1      1  4.0  350.0      2
# 2      1  8.0  675.0     14
# 3      1  4.0  180.0      6
# 4      1  3.0  150.0      5

# %%
df2.drop(['bike_name','city'],axis=1,inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8708\1642961446.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(['bike_name','city'],axis=1,inplace=True)

# %%
df2.head()
# Out:
#       price  kms_driven  owner  age  power  brand
# 0   35000.0     17654.0      1  3.0  110.0      6
# 1  119900.0     11000.0      1  4.0  350.0      2
# 2  600000.0       110.0      1  8.0  675.0     14
# 3   65000.0     16329.0      1  4.0  180.0      6
# 4   80000.0     10000.0      1  3.0  150.0      5

# %%
# Supervised learning   y--> price remaining x
x = df2.drop('price',axis=1) # independent variable
x
# Out:
#       kms_driven  owner  age  power  brand
# 0        17654.0      1  3.0  110.0      6
# 1        11000.0      1  4.0  350.0      2
# 2          110.0      1  8.0  675.0     14
# 3        16329.0      1  4.0  180.0      6
# 4        10000.0      1  3.0  150.0      5
# ...          ...    ...  ...    ...    ...
# 9362     48587.0      1  8.0  150.0      3
# 9369     60000.0      1  9.0  220.0      1
# 9370      3430.0      1  4.0  750.0      9
# 9371     21300.0      1  4.0  400.0      1
# 9372      7127.0      1  5.0  220.0      1
#
# [7307 rows x 5 columns]

# %%
y = df2[['price']] # dependent variable
y
# Out:
#          price
# 0      35000.0
# 1     119900.0
# 2     600000.0
# 3      65000.0
# 4      80000.0
# ...        ...
# 9362   25000.0
# 9369   35000.0
# 9370  450000.0
# 9371  139000.0
# 9372   80000.0
#
# [7307 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lnr = LinearRegression()

# %%
lnr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Model Evaluation
print("Training Score : ",lnr.score(x_train,y_train)*100)
# Out:
# Training Score :  73.54984712199813

# %%
print("Testing Score : ",lnr.score(x_test,y_test)*100)
# Out:
# Testing Score :  76.50217930524714

# %%
x_test.shape
# Out:
# (1462, 5)

# %%
prediction = lnr.predict(x_test)

# %%
prediction.shape
# Out:
# (1462, 1)

# %%
comparedf = pd.concat([x_test,y_test],axis=1)

# %%
comparedf['prediction'] = prediction

# %%
comparedf.head(40)
# Out:
#       kms_driven  owner   age  power  brand     price     prediction
# 2628     55000.0      2  11.0  150.0      1   16400.0  -10687.691185
# 761      48000.0      1  12.0  500.0      2  100000.0  200135.601862
# 4904     15000.0      2   6.0  150.0      8   35900.0   92796.297145
# 8709     24800.0      1   7.0  350.0      2   83000.0  133176.440534
# 6010     15768.0      1   6.0  125.0      4   28000.0   38665.227114
# 395      15000.0      1   2.0  200.0      1  130000.0   52807.284379
# 2488      4136.0      1   3.0  310.0      6  190000.0  173373.506939
# 2660     17000.0      1   5.0  500.0      2  122400.0  220880.266147
# 4788      8000.0      1   4.0  250.0      7  160000.0  150200.811145
# 4896     10703.0      1   4.0  150.0      4   60000.0   57973.972668
# 8325      7456.0      1   4.0  150.0      5   91000.0   70688.285508
# 8105     23500.0      1   8.0  125.0      4   28499.0   32815.274790
# 2655     50697.0      1   8.0  500.0      2  110000.0  210591.117605
# 6470     36000.0      1   9.0  150.0      5   47000.0   55432.062845
# 1102     21483.0      1   3.0  200.0      6   67000.0  112162.136299
# 174      10407.0      1   5.0  150.0      5   68000.0   67826.005004
# 4300     14000.0      1   5.0  200.0      6   62000.0  107354.713417
# 5258     42000.0      2  11.0  100.0      3   19600.0  -12096.346706
# 2287     20127.0      1   4.0  150.0      1   29156.0   19852.754938
# 3876     16230.0      1   9.0  160.0      6   23000.0   74735.143348
# 5367      7018.0      1   4.0  150.0      5   80000.0   70718.297200
# 138      32734.0      1   6.0  220.0      1   55000.0   51865.068207
# 3186     10784.0      2   5.0  150.0      5  100000.0   58269.768543
# 3397     29000.0      2   6.0  200.0      1   44000.0   31677.288304
# 5813     15525.0      1  12.0  350.0      2   95000.0  120511.569891
# 2860     60000.0      1   4.0  350.0      2  100000.0  138744.777311
# 1617     72000.0      1   8.0  223.0      3   60000.0   70475.053175
# 8391     10000.0      1   7.0  223.0      3   90000.0   77383.362009
# 3781     64323.0      1  11.0  125.0      4   13000.0   22037.853832
# 1594     40000.0      1   9.0  350.0      2   89600.0  126814.782007
# 1708     19000.0      1   9.0  883.0      9  400000.0  506534.041273
# 8599      3000.0      1   4.0  125.0      4   55000.0   44860.245378
# 7434     29800.0      1   7.0  150.0      5   50000.0   61177.042767
# 516       1500.0      1   3.0  110.0      4   53400.0   39438.182192
# 6682     48000.0      1   4.0  150.0      5   83000.0   67910.216910
# 8869     18894.0      1  11.0  350.0      2   85000.0  122940.804975
# 3739     13000.0      1   8.0  223.0      3   55000.0   74517.724033
# 3130     14978.0      1   9.0  100.0      3   22000.0    4605.757908
# 5526      9833.0      1   5.0  160.0      6   41000.0   85813.778561
# 2846     27623.0      1   5.0  350.0      2  104000.0  138303.165894

# %%
comparedf['residual'] = comparedf['price'] - comparedf['prediction']

# %%
comparedf.head(10)
# Out:
#       kms_driven  owner   age  power  brand     price     prediction  \
# 2628     55000.0      2  11.0  150.0      1   16400.0  -10687.691185
# 761      48000.0      1  12.0  500.0      2  100000.0  200135.601862
# 4904     15000.0      2   6.0  150.0      8   35900.0   92796.297145
# 8709     24800.0      1   7.0  350.0      2   83000.0  133176.440534
# 6010     15768.0      1   6.0  125.0      4   28000.0   38665.227114
# 395      15000.0      1   2.0  200.0      1  130000.0   52807.284379
# 2488      4136.0      1   3.0  310.0      6  190000.0  173373.506939
# 2660     17000.0      1   5.0  500.0      2  122400.0  220880.266147
# 4788      8000.0      1   4.0  250.0      7  160000.0  150200.811145
# 4896     10703.0      1   4.0  150.0      4   60000.0   57973.972668
#
#            residual
# 2628   27087.691185
# 761  -100135.601862
# 4904  -56896.297145
# 8709  -50176.440534
# 6010  -10665.227114
# 395    77192.715621
# 2488   16626.493061
# 2660  -98480.266147
# 4788    9799.188855
# 4896    2026.027332

# %%
# prediction
unseen_bike = [[3500,2,2,220,3]]
price_of_unseen_bike = lnr.predict(unseen_bike)
price_of_unseen_bike
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[79961.74444937]])

# %%
# Saving models
import os,joblib

# %%
os.makedirs('models',exist_ok=True)

# %%
lnr
# Out:
# LinearRegression()

# %%
joblib.dump(lnr,'./models/lineraRegression.lb')
# Out:
# ['./models/lineraRegression.lb']
