# %%
# Machine Learning ML
# sklearn library will be needed for ml 
# Linear Regression

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

df = pd.read_csv('Used_Bikes.csv')
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
# duplicates record
print("Number of Duplicated Record : ",df.duplicated().sum())
# Out:
# Number of Duplicated Record :  25324

# %%
df.drop_duplicates(inplace=True)
print("Duplicates Removed!")
# Out:
# Duplicates Removed!

# %%
print("Number of Duplicated Record : ",df.duplicated().sum())
# Out:
# Number of Duplicated Record :  0

# %%
print("Total number of bike Record : ",df.shape[0])
# Out:
# Total number of bike Record :  7324

# %%
# missing value check in data
df.isnull().sum()
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
# ML only deals with numerical value
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
cat_col = df.select_dtypes(include='O')
cat_col.head()
# Out:
#                               bike_name       city        owner          brand
# 0    TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner            TVS
# 1           Royal Enfield Classic 350cc      Delhi  First Owner  Royal Enfield
# 2                  Triumph Daytona 675R      Delhi  First Owner        Triumph
# 3                  TVS Apache RTR 180cc  Bangalore  First Owner            TVS
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner         Yamaha

# %%
num_col = df.select_dtypes(exclude='O')
num_col
# Out:
#          price  kms_driven  age  power
# 0      35000.0     17654.0  3.0  110.0
# 1     119900.0     11000.0  4.0  350.0
# 2     600000.0       110.0  8.0  675.0
# 3      65000.0     16329.0  4.0  180.0
# 4      80000.0     10000.0  3.0  150.0
# ...        ...         ...  ...    ...
# 9362   25000.0     48587.0  8.0  150.0
# 9369   35000.0     60000.0  9.0  220.0
# 9370  450000.0      3430.0  4.0  750.0
# 9371  139000.0     21300.0  4.0  400.0
# 9372   80000.0      7127.0  5.0  220.0
#
# [7324 rows x 4 columns]

# %%
cat_col['owner'].value_counts()
# Out:
# owner
# First Owner             6642
# Second Owner             588
# Third Owner               84
# Fourth Owner Or More      10
# Name: count, dtype: int64

# %%
# Data Transformation
dt = {'First Owner':1,'Second Owner':2,'Third Owner':3,
      'Fourth Owner Or More':4}
dt
# Out:
# {'First Owner': 1,
#  'Second Owner': 2,
#  'Third Owner': 3,
#  'Fourth Owner Or More': 4}

# %%
df['owner'] = df['owner'].map(dt) # single time execute

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#       owner  age  power            brand
# 0         1  3.0  110.0              TVS
# 1         1  4.0  350.0    Royal Enfield
# 2         1  8.0  675.0          Triumph
# 3         1  4.0  180.0              TVS
# 4         1  3.0  150.0           Yamaha
# ...     ...  ...    ...              ...
# 9362      1  8.0  150.0             Hero
# 9369      1  9.0  220.0            Bajaj
# 9370      1  4.0  750.0  Harley-Davidson
# 9371      1  4.0  400.0            Bajaj
# 9372      1  5.0  220.0            Bajaj
#
# [7324 rows x 8 columns]

# %%
df['brand'].value_counts()
# Out:
# brand
# Bajaj              2081
# Royal Enfield      1346
# Hero               1142
# Honda               676
# Yamaha              651
# TVS                 481
# KTM                 375
# Suzuki              203
# Harley-Davidson      91
# Kawasaki             61
# Hyosung              53
# Mahindra             50
# Benelli              46
# Triumph              21
# Ducati               20
# BMW                  10
# Jawa                  7
# Indian                3
# MV                    3
# Rajdoot               1
# LML                   1
# Yezdi                 1
# Ideal                 1
# Name: count, dtype: int64

# %%
# Get the brands that appear at least 10 times
bike_brand = list(df['brand'].value_counts().head(16).index)
bike_brand
# Out:
# ['Bajaj',
#  'Royal Enfield',
#  'Hero',
#  'Honda',
#  'Yamaha',
#  'TVS',
#  'KTM',
#  'Suzuki',
#  'Harley-Davidson',
#  'Kawasaki',
#  'Hyosung',
#  'Mahindra',
#  'Benelli',
#  'Triumph',
#  'Ducati',
#  'BMW']

# %%
df2 = df[df['brand'].isin(bike_brand)]
df2.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#    owner  age  power          brand
# 0      1  3.0  110.0            TVS
# 1      1  4.0  350.0  Royal Enfield
# 2      1  8.0  675.0        Triumph
# 3      1  4.0  180.0            TVS
# 4      1  3.0  150.0         Yamaha

# %%
br = {'Bajaj':1,
 'Royal Enfield':2,
 'Hero':3,
 'Honda':4,
 'Yamaha':5,
 'TVS':6,
 'KTM':7,
 'Suzuki':8,
 'Harley-Davidson':9,
 'Kawasaki':10,
 'Hyosung':11,
 'Mahindra':12,
 'Benelli':13,
 'Triumph':14,
 'Ducati':15,
 'BMW':16}

df2['brand'] = df2['brand'].map(br) # label encoding
df2.head()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_19108\936175165.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['brand'] = df2['brand'].map(br) # label encoding
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#    owner  age  power  brand
# 0      1  3.0  110.0      6
# 1      1  4.0  350.0      2
# 2      1  8.0  675.0     14
# 3      1  4.0  180.0      6
# 4      1  3.0  150.0      5

# %%
df2.drop(['bike_name','city'],axis=1,inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_19108\1642961446.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(['bike_name','city'],axis=1,inplace=True)

# %%
df2.head()
# Out:
#       price  kms_driven  owner  age  power  brand
# 0   35000.0     17654.0      1  3.0  110.0      6
# 1  119900.0     11000.0      1  4.0  350.0      2
# 2  600000.0       110.0      1  8.0  675.0     14
# 3   65000.0     16329.0      1  4.0  180.0      6
# 4   80000.0     10000.0      1  3.0  150.0      5

# %%
# Supervised learning   y--> price remaining x
x = df2.drop('price',axis=1) # independent variable
x
# Out:
#       kms_driven  owner  age  power  brand
# 0        17654.0      1  3.0  110.0      6
# 1        11000.0      1  4.0  350.0      2
# 2          110.0      1  8.0  675.0     14
# 3        16329.0      1  4.0  180.0      6
# 4        10000.0      1  3.0  150.0      5
# ...          ...    ...  ...    ...    ...
# 9362     48587.0      1  8.0  150.0      3
# 9369     60000.0      1  9.0  220.0      1
# 9370      3430.0      1  4.0  750.0      9
# 9371     21300.0      1  4.0  400.0      1
# 9372      7127.0      1  5.0  220.0      1
#
# [7307 rows x 5 columns]

# %%
y = df2[['price']] # dependent variable
y
# Out:
#          price
# 0      35000.0
# 1     119900.0
# 2     600000.0
# 3      65000.0
# 4      80000.0
# ...        ...
# 9362   25000.0
# 9369   35000.0
# 9370  450000.0
# 9371  139000.0
# 9372   80000.0
#
# [7307 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lnr = LinearRegression()

# %%
lnr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Model Evaluation
print("Training Score : ",lnr.score(x_train,y_train)*100)
# Out:
# Training Score :  73.87682315547781

# %%
print("Testing Score : ",lnr.score(x_test,y_test)*100)
# Out:
# Testing Score :  74.4702969190463

# %%
x_test.shape
# Out:
# (1462, 5)

# %%
prediction = lnr.predict(x_test)

# %%
prediction.shape
# Out:
# (1462, 1)

# %%
comparedf = pd.concat([x_test,y_test],axis=1)

# %%
comparedf['prediction'] = prediction

# %%
comparedf.head(40)
# Out:
#       kms_driven  owner   age  power  brand     price     prediction
# 1453     20208.0      1   6.0  100.0      3   30000.0   13362.439117
# 1642     39000.0      1   7.0  350.0      2   95000.0  130153.741623
# 8669     27228.0      1  16.0  150.0      1   10000.0  -12923.645327
# 8067      8500.0      1   5.0  350.0      2  128000.0  138056.500255
# 4637      4459.0      1   4.0  250.0     11  260000.0  197679.478423
# 7052     67945.0      1  11.0  100.0      1   15000.0  -28641.753652
# 2683      7600.0      1   8.0  220.0      1   40000.0   48255.541579
# 393       5000.0      1   2.0  150.0      4   89000.0   64552.239583
# 382      20000.0      1   8.0  160.0      6   31500.0   76349.876803
# 2965      8331.0      1   3.0  160.0      4   81300.0   66829.356207
# 9012     19000.0      1   6.0  350.0      2  115000.0  134463.823698
# 8010     23000.0      1   6.0  150.0      4   55000.0   51993.926247
# 3483     24000.0      1   5.0  220.0      1   74000.0   55416.337106
# 2928     23905.0      1   7.0  125.0      4   35000.0   35804.788461
# 7149     13431.0      1   6.0  350.0      2   99000.0  134884.374365
# 6493     19000.0      1   7.0  150.0      1   30000.0   12895.495374
# 2198      6500.0      1   5.0  150.0      4  100000.0   56039.701026
# 5849     89999.0      1   4.0  100.0      3   26365.0   13691.585443
# 8088     16051.0      1   6.0  250.0     11  175000.0  191204.583323
# 5556     21500.0      2   6.0  150.0      5   49999.0   56615.493572
# 8337     21200.0      1  10.0  150.0      5   52000.0   53131.084274
# 7117     40588.0      1   7.0  150.0      1   35000.0   11265.247969
# 6368     21326.0      1   7.0  100.0      3   30000.0   10478.257148
# 8074     12061.0      1   4.0  180.0      6   65000.0   98805.252580
# 491       6518.0      1   4.0  350.0      2  126000.0  141005.928368
# 1313       167.0      1   2.0  390.0      7  180000.0  229399.943602
# 9341     11122.0      1  11.0  100.0      3   25000.0      49.807522
# 5313     28808.0      1   7.0  100.0      1   21000.0  -14487.250794
# 1370      8047.0      1   5.0  350.0      2   95100.0  138090.709170
# 8365    194992.0      1  11.0  500.0      2  110000.0  187101.018120
# 6741     44004.0      1  14.0  125.0      1   12000.0  -21912.039426
# 5119     25000.0      1   9.0  150.0      3   28000.0   31243.382275
# 5120     16000.0      2   7.0  200.0      7  120000.0  105273.655008
# 4320     17565.0      1   7.0  100.0      1   19000.0  -13638.220242
# 4798     17989.0      1  11.0  100.0      3   18000.0    -468.763393
# 5263      9119.0      1   5.0  200.0      1  110000.0   45883.263571
# 4156     26000.0      1   8.0  100.0      3   24000.0    7325.538965
# 8058     14396.0      1   7.0  350.0      2   75000.0  132011.746400
# 675      39450.0      1  14.0  135.0      1   20300.0  -16239.721554
# 2142     11000.0      2  10.0  350.0      2   71000.0  116176.981534

# %%
comparedf['residual'] = comparedf['price'] - comparedf['prediction']

# %%
comparedf.head(10)
# Out:
#       kms_driven  owner   age  power  brand     price     prediction  \
# 1453     20208.0      1   6.0  100.0      3   30000.0   13362.439117
# 1642     39000.0      1   7.0  350.0      2   95000.0  130153.741623
# 8669     27228.0      1  16.0  150.0      1   10000.0  -12923.645327
# 8067      8500.0      1   5.0  350.0      2  128000.0  138056.500255
# 4637      4459.0      1   4.0  250.0     11  260000.0  197679.478423
# 7052     67945.0      1  11.0  100.0      1   15000.0  -28641.753652
# 2683      7600.0      1   8.0  220.0      1   40000.0   48255.541579
# 393       5000.0      1   2.0  150.0      4   89000.0   64552.239583
# 382      20000.0      1   8.0  160.0      6   31500.0   76349.876803
# 2965      8331.0      1   3.0  160.0      4   81300.0   66829.356207
#
#           residual
# 1453  16637.560883
# 1642 -35153.741623
# 8669  22923.645327
# 8067 -10056.500255
# 4637  62320.521577
# 7052  43641.753652
# 2683  -8255.541579
# 393   24447.760417
# 382  -44849.876803
# 2965  14470.643793

# %%
# prediction
unseen_bike = [[3500,2,2,220,3]]
price_of_unseen_bike = lnr.predict(unseen_bike)
price_of_unseen_bike
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[82072.22670021]])

# %%
# Saving models
import os,joblib

# %%
os.makedirs('models',exist_ok=True)

# %%
lnr
# Out:
# LinearRegression()

# %%
joblib.dump(lnr,'./models/lineraRegression.lb')
# Out:
# ['./models/lineraRegression.lb']
